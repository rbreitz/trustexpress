# %% [markdown]
# This notebook is for exploring the Week 1 collected data.

# %%
#Import some relevant packages
import csv
import requests

#For working with SQL in Python
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

#For generally exploring things within Python
import pandas as pd
import matplotlib as mpl

# %%
hot_this_week = pd.read_csv('lots_of_reviews_006.csv', index_col=0)

# %%
#Make a Database
# Define a database name (we're using a dataset on births, so we'll call it birth_db)
# Set your postgres username
dbname = 'reviews_db'
username = 'rebeccareitz' # change this to your username

## 'engine' is a connection to a database
## Here, we're using postgres, but sqlalchemy can connect to other things too.
engine = create_engine('postgres://%s@localhost/%s'%(username,dbname))
print(engine.url)

## create a database (if it doesn't exist)
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))
# Out:
# postgres://rebeccareitz@localhost/reviews_db
# True

# %%
## insert data into database from Python (proof of concept - this won't be useful for big data, of course)
hot_this_week.to_sql('review_table', engine, if_exists='replace')

# %%
#Connect and query

# Connect to make queries using psycopg2
con = None
con = psycopg2.connect(database = dbname, user = username)

# query:
sql_query = """
SELECT * FROM review_table;
"""
birth_data_from_sql = pd.read_sql_query(sql_query,con)
birth_data_from_sql.head()
# Out:
#    32317979982  False  US  100  \
# 0  32317979982  False  US  100
# 1  32317979982  False  US   80
# 2  32317979982  False  US  100
# 3  32317979982  False  US  100
# 4  32317979982  False  US  100
#
#                   ОТЛИЧНЫЙ КУПАЛЬНИК. ДЕВОЧКА 9 ЛЕТ. Unnamed: 5  \
# 0  Очень красивый, яркий купальник на девочку 9-1...       None
# 1  quality is very good but size is very Small. I...       None
# 2                                               None          F
# 3                                               None          F
# 4                                               None       None
#
#                                           Unnamed: 6    1611199947  \
# 0                                               None  1.738247e+09
# 1                                               None  9.192527e+08
# 2  https://gw.alicdn.com/tps/TB1zA01LXXXXXc0XFXXX...  7.254183e+08
# 3  https://gw.alicdn.com/tps/TB1zA01LXXXXXc0XFXXX...  7.387970e+08
# ...

# %%
hot_this_week = pd.read_csv('lots_of_reviews_003.csv')
hot_this_week.head()
# Out:
#     product_id anonymous buyerCountry buyerEval  \
# 0  32243608596     False           US       100
# 1  32243608596     False           US        80
# 2  32243608596     False           US       100
# 3  32243608596     False           US       100
# 4  32243608596     False           US       100
#
#                                        buyerFeedback buyerGender  \
# 0  Great fabric and quality, fast delivery and co...         NaN
# 1  Me gusto mucho igual que la presentación, nada...           F
# 2                                                NaN           F
# 3                                                NaN         NaN
# 4                                            thanks!           F
#
#                                    buyerHeadPortrait     buyerId  \
# 0  https://ae01.alicdn.com/kf/UTB8vTH0hFPJXKJkSah...   230419691
# 1  https://ae01.alicdn.com/kf/UTB8lUMuipPJXKJkSah...  1678569385
# 2  https://ae01.alicdn.com/kf/UTB8upYOXSbIXKJkSae...   127741530
# ...

# %%
new_header = hot_this_week.columns.values
print(new_header)
# Out:
# ['product_id' 'anonymous' 'buyerCountry' 'buyerEval' 'buyerFeedback'
#  'buyerGender' 'buyerHeadPortrait' 'buyerId' 'buyerName' 'evalDate'
#  'image' 'logistics' 'skuInfo' 'thumbnail']

# %%
df_bad_header = pd.read_csv('lots_of_reviews_005.csv')
df_bad_header.head()
# Out:
#    32317979982  False  US  100  \
# 0  32317979982  False  US  100
# 1  32317979982  False  US   80
# 2  32317979982  False  US  100
# 3  32317979982  False  US  100
# 4  32317979982  False  US  100
#
#                   ОТЛИЧНЫЙ КУПАЛЬНИК. ДЕВОЧКА 9 ЛЕТ. Unnamed: 5  \
# 0  Очень красивый, яркий купальник на девочку 9-1...        NaN
# 1  quality is very good but size is very Small. I...        NaN
# 2                                                NaN          F
# 3                                                NaN          F
# 4                                                NaN        NaN
#
#                                           Unnamed: 6    1611199947  \
# 0                                                NaN  1.738247e+09
# 1                                                NaN  9.192527e+08
# 2  https://gw.alicdn.com/tps/TB1zA01LXXXXXc0XFXXX...  7.254183e+08
# 3  https://gw.alicdn.com/tps/TB1zA01LXXXXXc0XFXXX...  7.387970e+08
# ...

# %%
bad_headers=df_bad_header.columns.values

# %%
header_dict = dict(zip(bad_headers,new_header))

# %%
df_bad_header.rename(columns = header_dict)
# Out:
#        product_id  anonymous buyerCountry  buyerEval  \
# 0     32317979982      False           US        100
# 1     32317979982      False           US         80
# 2     32317979982      False           US        100
# 3     32317979982      False           US        100
# 4     32317979982      False           US        100
# 5     32317979982      False           US        100
# 6     32317979982       True           US         80
# 7     32317979982       True           US        100
# 8     32317979982       True           US         80
# 9     32317979982      False           US         80
# 10    32317979982      False           US        100
# 11    32317979982      False           US        100
# 12    32317979982      False           US        100
# 13    32317979982      False           US         80
# 14    32317979982      False           US        100
# 15    32317979982      False           US        100
# 16    32317979982      False           US        100
# ...

# %%
big_df = pd.read_csv('all_reviews_13_09_18.csv', index_col=0, low_memory=False)

# %%
big_df.shape
# Out:
# (42250, 28)

# %%
def load_df_replace_header(filename):
    df = pd.read_csv(filename)
    bad_headers = df.columns.values
    header_dict = dict(zip(bad_headers,new_header))
    df_new_heads = df.rename(columns=header_dict)
    return df_new_heads

# %%
df_current = load_df_replace_header('necklaces_reviews_001.csv')

# %%
df_current.head()
# Out:
#     product_id  anonymous buyerCountry  buyerEval  \
# 0  32874530679      False           US        100
# 1  32874530679      False           US         60
# 2  32874530679      False           US        100
# 3  32874530679      False           US        100
# 4  32874530679      False           US        100
#
#                                        buyerFeedback buyerGender  \
# 0  Кулончик отримала,за 2 тижні,одне що жилку пот...           F
# 1            очень большая цепочка, ожидала поменьше           F
# 2  Thanks this is the same as the other one, I go...         NaN
# 3       Fits awesome. Great Material. It fits per...         NaN
# 4  I love it. Just like the picture. Maybe even b...         NaN
#
#                                    buyerHeadPortrait       buyerId  \
# 0  https://ae01.alicdn.com/kf/UTB8T4SlBwQydeJk43P...  9.073516e+08
# 1  https://ae01.alicdn.com/kf/UTB8WAH7hD_IXKJkSal...  1.695692e+09
# ...

# %%
big_df_15 = pd.concat([big_df_14,df_current], ignore_index = True, sort=False)

# %%
big_df_now = big_df_15
big_df_now.shape
# Out:
# (125384, 28)

# %%
big_df_now.to_csv('all_reviews_17_09_18.csv')

# %%
big_df_3 = pd.concat([big_df_2,df_smart], ignore_index = True, sort=False)

# %%
big_df_3.shape
# Out:
# (18516, 28)

# %%
df_memory = load_df_replace_header('memory_card_reviews_001.csv')

# %%
big_df_4 = pd.concat([big_df_3,df_memory], ignore_index = True, sort=False)
big_df_4.shape
# Out:
# (22853, 28)

# %%
df_cables = load_df_replace_header('cables_reviews_001.csv')

# %%
big_df_5 = pd.concat([big_df_4,df_cables], ignore_index = True, sort=False)
big_df_5.shape
# Out:
# (27192, 28)

# %%
df_mens = load_df_replace_header('mens_clothes_reviews_001.csv')

# %%
big_df_6 = pd.concat([big_df_5,df_mens], ignore_index = True, sort=False)
big_df_6.shape
# Out:
# (31562, 28)

# %%
df_cell_acc = load_df_replace_header('cell_phone_accessories_reviews_001.csv')

# %%
big_df_7 = pd.concat([big_df_6,df_cell_acc], ignore_index = True, sort=False)
big_df_7.shape
# Out:
# (35247, 28)

# %%
df_woman = load_df_replace_header('womens_clothes_reviews_001.csv')

# %%
big_df_8 = pd.concat([big_df_7,df_woman], ignore_index = True, sort=False)
big_df_8.shape
# Out:
# (37548, 28)

# %%
df_office = load_df_replace_header('office_electronics_reviews_001.csv')

# %%
big_df_9 = pd.concat([big_df_8,df_office], ignore_index = True, sort=False)
big_df_9.shape
# Out:
# (39179, 28)

# %%
df_home = load_df_replace_header('home_audio_reviews_001.csv')

# %%
big_df_10 = pd.concat([big_df_9,df_home], ignore_index = True, sort=False)
big_df_10.shape
# Out:
# (40744, 28)

# %%
df_component = load_df_replace_header('computer_component_reviews_001.csv')

# %%
big_df_11 = pd.concat([big_df_10,df_component], ignore_index = True, sort=False)
big_df_11.shape
# Out:
# (41775, 28)

# %%
df_peripheral = load_df_replace_header('computer_peripherals_reviews_001.csv')

# %%
big_df_12 = pd.concat([big_df_11,df_peripheral], ignore_index = True, sort=False)
big_df_12.shape
# Out:
# (42250, 28)

# %%
big_df_12.to_csv('all_reviews_13_09_18.csv')

# %%
big_df_12['buyerFeedback']
# Out:
# 0        Great fabric and quality, fast delivery and co...
# 1        Me gusto mucho igual que la presentación, nada...
# 2                                                      NaN
# 3                                                      NaN
# 4                                                  thanks!
# 5                                   not bad for such price
# 6                                                      NaN
# 7        nice cap, my boyfriend is very happy with it. ...
# 8                                  Good just little stain
# 9                                                      NaN
# 10                                perfect, adjustable size
# 11                             All stained. Terrible goods
# 12                                                     NaN
# 13       Well made. Seems to be a one size fits all of ...
# 14                                                     NaN
# 15       Nice cap in good quality. Oryginally was too b...
# ...

# %%
import matplotlib.pyplot as plt

# %%
big_df = pd.read_csv('all_reviews_17_09_18.csv', index_col=0, low_memory=False)
big_df.head()
# Out:
#     product_id anonymous buyerCountry buyerEval  \
# 0  32243608596     False           US       100
# 1  32243608596     False           US        80
# 2  32243608596     False           US       100
# 3  32243608596     False           US       100
# 4  32243608596     False           US       100
#
#                                        buyerFeedback buyerGender  \
# 0  Great fabric and quality, fast delivery and co...         NaN
# 1  Me gusto mucho igual que la presentación, nada...           F
# 2                                                NaN           F
# 3                                                NaN         NaN
# 4                                            thanks!           F
#
#                                    buyerHeadPortrait     buyerId  \
# 0  https://ae01.alicdn.com/kf/UTB8vTH0hFPJXKJkSah...   230419691
# 1  https://ae01.alicdn.com/kf/UTB8lUMuipPJXKJkSah...  1678569385
# 2  https://ae01.alicdn.com/kf/UTB8upYOXSbIXKJkSae...   127741530
# ...

# %%
common_reviewers = big_df['buyerId'].value_counts()

# %%
common_reviewers
# Out:
# 104950247.0     275
# 1679959340.0    144
# buyerId          56
# 188642918.0      55
# 120095941.0      23
# 753376930.0      16
# 230978574.0      15
# 927315042.0      10
# 904767815.0      10
# 195417695.0      10
# 1795716940.0      9
# 924723896.0       9
# 138744143.0       9
# 138655426.0       8
# 916342631.0       8
# 186883328.0       8
# 1651236413.0      8
# 910381248.0       8
# 793853785.0       8
# 1612767300.0      8
# 786456751.0       8
# 747693233.0       7
# 882013512.0       7
# 1620203290.0      7
# 808207764.0       7
# 137656123.0       7
# 865599961.0       7
# 117413593.0       7
# 899152310.0       7
# 882970846.0       7
#                ...
# 1619208470.0      1
# 729123963.0       1
# 737747105.0       1
# 847983518.0       1
# 784017914.0       1
# 763002379         1
# 830483248.0       1
# 771481739.0       1
# 759907795.0       1
# 1614590794.0      1
# 1793669473.0      1
# 849962477.0       1
# 709475643.0       1
# 1694038107.0      1
# ...

# %%
# %matplotlib inline
plt.pie(common_reviewers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-cced044a3f89> in <module>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 plt.pie(common_reviewers)
#
# NameError: name 'plt' is not defined

# %%
reviewer_profile = big_df.loc[big_df['buyerId']>188642917]
reviewer_profile.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-d31153d26330> in <module>()
# ----> 1 reviewer_profile = big_df.loc[big_df['buyerId']>188642917]
#       2 reviewer_profile.head()
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1251
#    1252             with np.errstate(all='ignore'):
# -> 1253                 res = na_op(values, other)
#    1254             if is_scalar(res):
#    1255                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1138
#    1139         elif is_object_dtype(x.dtype):
# -> 1140             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1141
#    1142         elif is_datetimelike_v_numeric(x, y):
#
# ...
